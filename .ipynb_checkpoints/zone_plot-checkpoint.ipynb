# %%
# <!-- collapse=True -->
import bokeh, bokeh.plotting, bokeh.models
from bokeh.io import output_notebook, show
output_notebook()

import geopandas as gpd
from shapely.geometry import Point
import urllib
import dask.dataframe as dd
import dask.distributed
import numpy as np

import sklearn.preprocessing

client = dask.distributed.Client()

coord_system = {'init': 'epsg:4326'}
df = gpd.read_file('./taxi_zones/taxi_zones_new.shp').to_crs(coord_system)
df = df.drop(['Shape_Area', 'Shape_Leng', 'OBJECTID'], axis=1)
df.head()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="59ddf1a3-7382-4be9-9ca8-ceb1b0e061d9">Loading BokehJS ...</span>
#     </div>
#    LocationID        borough  \
# 0           1            EWR
# 1           2         Queens
# 2           3          Bronx
# 3           4      Manhattan
# 4           5  Staten Island
#
#                                             geometry                     zone
# 0  POLYGON ((-74.18445299999998 40.6949959999999,...           Newark Airport
# 1  (POLYGON ((-73.82337597260664 40.6389870471767...              Jamaica Bay
# 2  POLYGON ((-73.84792614099986 40.87134223399993...  Allerton/Pelham Gardens
# 3  POLYGON ((-73.9717741096532 40.72582128133706,...            Alphabet City
# 4  POLYGON ((-74.17421738099991 40.56256808599989...            Arden Heights

# %%
# <!-- collapse=True -->
gjds = bokeh.models.GeoJSONDataSource(geojson=df.to_json())
TOOLS = "pan,wheel_zoom,reset,hover,save"

p = bokeh.plotting.figure(title="NYC Taxi Districts", tools=TOOLS,
    x_axis_location=None, y_axis_location=None, 
    responsive=True)

color_mapper = bokeh.models.LinearColorMapper(palette=bokeh.palettes.Viridis256)

p.patches('xs', 'ys', 
          fill_color={'field': 'LocationID', 'transform': color_mapper},
          fill_alpha=1., line_color="black", line_width=0.5,          
          source=gjds)

p.grid.grid_line_color = None

hover = p.select_one(bokeh.models.HoverTool)
hover.point_policy = "follow_mouse"
hover.tooltips = u"""
<div> 
    <div class="bokeh_hover_tooltip">Name : @zone</div>
    <div class="bokeh_hover_tooltip">Borough : @borough</div>
    <div class="bokeh_hover_tooltip">Zone ID : @LocationID</div>
    <div class="bokeh_hover_tooltip">(Lon, Lat) : ($x ˚E, $y ˚N)</div>
</div>
"""

p.circle([-73.966,], [40.78,], size=10, fill_color='magenta', line_color='yellow', line_width=1, alpha=1.0)

show(p)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
# <!-- collapse=True -->
df2 = df.copy()
df2['geometry'] = df.geometry.envelope
df2['borough_categ'] = sklearn.preprocessing.LabelEncoder().fit_transform(df2['borough'])
gjds2 = bokeh.models.GeoJSONDataSource(geojson=df2.to_json())

TOOLS = "pan,wheel_zoom,reset,hover,save"

p = bokeh.plotting.figure(title="NYC Taxi Districts Bounding Boxes", tools=TOOLS,
    x_axis_location=None, y_axis_location=None, 
    responsive=True)

color_mapper = bokeh.models.LinearColorMapper(palette=bokeh.palettes.Viridis256)

p.patches('xs', 'ys', 
          fill_color={'field': 'borough_categ', 'transform': color_mapper},
          fill_alpha=0.7, line_color="black", line_width=0.5,          
          source=gjds2)

p.grid.grid_line_color = None

hover = p.select_one(bokeh.models.HoverTool)
hover.point_policy = "follow_mouse"
hover.tooltips = u"""
<div> 
    <div class="bokeh_hover_tooltip">Name : @zone</div>
    <div class="bokeh_hover_tooltip">Borough : @borough</div>
    <div class="bokeh_hover_tooltip">Zone ID : @LocationID</div>
    <div class="bokeh_hover_tooltip">(Lon, Lat) : ($x ˚E, $y ˚N)</div>
</div>
"""

p.circle([-73.966,], [40.78,], size=10, fill_color='magenta', line_color='yellow', line_width=1, alpha=1.0)

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="bffa80ba-c2b5-415a-b22c-7272a2e2d352"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("bffa80ba-c2b5-415a-b22c-7272a2e2d352");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("bffa80ba-c2b5-415a-b22c-7272a2e2d352");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'bffa80ba-c2b5-415a-b22c-7272a2e2d352' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"656d509b-bb52-4326-999a-4e5ac2de1010":{"roots":{"references":[{"attributes":{"plot":{"id":"319199a2-b33e-4fb2-97fd-a7c472e43770","subtype":"Figure","type":"Plot"}},"id":"746861cd-50bd-4964-a8b8-0e8c18602006","type":"WheelZoomTool"},{"attributes":{},"id":"efaf4fae-e40e-46ba-9686-67791c100cba","type":"BasicTicker"},{"attributes":{},"id":"5cd3359a-2a3b-4eee-8049-f8370b5ee4ee","type":"LinearScale"},{"attributes":{"renderers":[{"id":"1fa9f96e-7f52-4293-8023-54b877e5fad5","type":"Grid"},{"id":"5b5877fe-88b7-432d-965d-3901d3384ff5","type":"Grid"},{"id":"dcd95802-1a2b-4685-ab0c-e4be199e81bf","type":"GlyphRenderer"},{"id":"03cadcea-d7c0-4e57-ac7c-b4a373dbd1a4","type":"GlyphRenderer"}],"sizing_mode":"scale_width","title":{"id":"1ba03c63-9aa0-46e2-958c-3b726959d0ed","type":"Title"},"tool_events":{"id":"faad05fa-ecbf-4cbe-a561-89af9caf494b","type":"ToolEvents"},"toolbar":{"id":"8071fb3d-9055-427f-91dd-61e2e317eda6","type":"Toolbar"},"x_range":{"id":"4b9ba064-32ab-452c-8445-ea0a2f092eac","type":"DataRange1d"},"x_scale":{"id":"7f874e65-5839-47be-88bc-71a2193d04f8","type":"LinearScale"},"y_range":{"id":"78b2fb5d-c767-4c3f-ae73-371580e5649c","type":"DataRange1d"},"y_scale":{"id":"5cd3359a-2a3b-4eee-8049-f8370b5ee4ee","type":"LinearScale"}},"id":"319199a2-b33e-4fb2-97fd-a7c472e43770","subtype":"Figure","type":"Plot"},{"attributes":{"data_source":{"id":"c47dc646-98c0-4811-a14a-e57d3127f1fa","type":"GeoJSONDataSource"},"glyph":{"id":"2ba1efe3-4a37-40d3-a3bc-5d8137339fcd","type":"Patches"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"771497c6-8609-4f82-8a27-2d4f804983e8","type":"Patches"},"selection_glyph":null},"id":"dcd95802-1a2b-4685-ab0c-e4be199e81bf","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"3b85754c-2468-4871-bbc0-e9018d9066d7","type":"ColumnDataSource"},"glyph":{"id":"303265cc-3011-4900-88b4-57bfd80a3b28","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"85eb70ab-b447-4b3b-b7cc-3ccecedd6133","type":"Circle"},"selection_glyph":null},"id":"03cadcea-d7c0-4e57-ac7c-b4a373dbd1a4","type":"GlyphRenderer"},{"attributes":{},"id":"faad05fa-ecbf-4cbe-a561-89af9caf494b","type":"ToolEvents"},{"attributes":{"grid_line_color":{"value":null},"plot":{"id":"319199a2-b33e-4fb2-97fd-a7c472e43770","subtype":"Figure","type":"Plot"},"ticker":{"id":"dcf8dac3-6e14-4656-b5dc-64bda8280554","type":"BasicTicker"}},"id":"1fa9f96e-7f52-4293-8023-54b877e5fad5","type":"Grid"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"field":"borough_categ","transform":{"id":"d315cd44-225a-435c-b290-9325aefb06be","type":"LinearColorMapper"}},"line_width":{"value":0.5},"xs":{"field":"xs"},"ys":{"field":"ys"}},"id":"2ba1efe3-4a37-40d3-a3bc-5d8137339fcd","type":"Patches"},{"attributes":{"plot":null,"text":"NYC Taxi Districts Bounding Boxes"},"id":"1ba03c63-9aa0-46e2-958c-3b726959d0ed","type":"Title"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":0.5},"xs":{"field":"xs"},"ys":{"field":"ys"}},"id":"771497c6-8609-4f82-8a27-2d4f804983e8","type":"Patches"},{"attributes":{"plot":{"id":"319199a2-b33e-4fb2-97fd-a7c472e43770","subtype":"Figure","type":"Plot"}},"id":"1ad25ff0-349d-4356-9a9f-7e34d0d68efe","type":"PanTool"},{"attributes":{},"id":"7f874e65-5839-47be-88bc-71a2193d04f8","type":"LinearScale"},{"attributes":{"fill_color":{"value":"magenta"},"line_color":{"value":"yellow"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"303265cc-3011-4900-88b4-57bfd80a3b28","type":"Circle"},{"attributes":{"callback":null,"plot":{"id":"319199a2-b33e-4fb2-97fd-a7c472e43770","subtype":"Figure","type":"Plot"},"point_policy":"follow_mouse","tooltips":"\n<div> \n    <div class=\"bokeh_hover_tooltip\">Name : @zone</div>\n    <div class=\"bokeh_hover_tooltip\">Borough : @borough</div>\n    <div class=\"bokeh_hover_tooltip\">Zone ID : @LocationID</div>\n    <div c ...
