# %%
import numpy as np
import pandas as pd
import seaborn as sns
from scipy import stats

from sqlalchemy import create_engine # database connection
import datetime as dt
from IPython.display import display

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Data during 2013 August, 12,597,109 rides in total

# %%
disk_engine = create_engine('sqlite:///trip_data_2013_08.db')

# %%
df = pd.read_sql_query('SELECT * FROM trip_data LIMIT 10', disk_engine)
df.tail(50)
# Out:
#    index  Unnamed: 0                         medallion  \
# 0      0           0  3418135604CD3F357DD9577AF978C5C0
# 1      1           1  6D3B2A7682C30DCF64F3F12976EF93B6
# 2      2           2  6D49E494913752B75B2685E0019FF3D5
# 3      3           3  4C4A0AFC432A1A87E97ED8F18403FF6E
# 4      4           4  1258CA1DF5E2A9E9A9F7848408A7AAEB
# 5      5           5  3B0E8DC736D1E0D35C698D7B0BF9CBFA
# 6      6           6  1A575E39B0D761E6496F002F79E34D19
# 7      7           7  A30A0C08B1331EC905B012947F22081F
# 8      8           8  EF74C4639B1D4D28B88DBCF0694DC821
# 9      9           9  C647516A7B73EC8105E8DE5494B4CDB9
#
#                        hack_license vendor_id  rate_code store_and_fwd_flag  \
# 0  B25386A1F259C87449430593E904FDBC       VTS          1               None
# 1  A603A9D5FAA46E8FF2A97A143328D938       CMT          1                  N
# 2  3F0BFE90A5D71741840B25600A89E225       CMT          1                  N
# ...

# %%
df = pd.read_sql_query('SELECT * FROM trip_data ORDER BY pickup_datetime ASC', disk_engine)
df.head()
# Out:
#    index  Unnamed: 0                         medallion  \
# 0  11901       12127  F5BD51C544CA21C66E7706716DA74D60
# 1   1904        1932  F5BD51C544CA21C66E7706716DA74D60
# 2  12249       12480  F5BD51C544CA21C66E7706716DA74D60
# 3  12849       13086  F5BD51C544CA21C66E7706716DA74D60
# 4  11902       12128  F5BD51C544CA21C66E7706716DA74D60
#
#                        hack_license vendor_id  rate_code store_and_fwd_flag  \
# 0  87761E7EE2E9F268E357C6BC66D99464       CMT          1                  Y
# 1  1E85B76B387E9439BF4B07F35F971B99       CMT          1                  Y
# 2  1E85B76B387E9439BF4B07F35F971B99       CMT          1                  N
# 3  1E85B76B387E9439BF4B07F35F971B99       CMT          1                  Y
# 4  1E85B76B387E9439BF4B07F35F971B99       CMT          1                  N
#
#        pickup_datetime     dropoff_datetime  passenger_count  \
# 0  2013-08-25 03:23:08  2013-08-25 03:31:09                1
# ...
